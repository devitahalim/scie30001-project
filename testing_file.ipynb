# %%
from SimulationOfGMM import SimulateGMM
from EstimationGMM import GaussianEM
import numpy as np
from scipy.stats import multivariate_normal

# %%
SimulateGMM(100,10,4,-5,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/devitahalim/hello/hello/GMM/testing_file.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/devitahalim/hello/hello/GMM/testing_file.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> SimulateGMM(100,10,4,-5,5)
#
# File ~/hello/hello/GMM/SimulationOfGMM.py:11, in SimulateGMM(n, mean1, sig1, mean2, sig2)
#       9 def SimulateGMM(n, mean1, sig1, mean2, sig2):
#      10     X=GMMData(n,mean1, sig1, mean2, sig2)
# ---> 11     np.random.shuffle(X)
#      13     #Plot the Gaussian and the data points
#      14     gmm_datapoints=np.linspace(np.min(X),np.max(X),100)
#
# File mtrand.pyx:4505, in numpy.random.mtrand.RandomState.shuffle()
#
# TypeError: object of type 'NoneType' has no len()

# %%
GaussianEM(X,2,15)
